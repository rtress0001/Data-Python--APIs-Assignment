# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
#help(requests)

# %%
url = 'http://ergast.com/api/f1/2008/5/driverStandings.json'

# %%
#response object
response = requests.get(url) 
#This display the whole data set
#response.json()

# %%
#check and make sure we got a successful response from the API
print(response)
type(response.json())
# Out:
# <Response [200]>
# dict

# %%
#view the response as a JSON

#This display the whole data set
#response.json()

# %%
# Out:
# {'water': ['squirtle', 'blastoise', 'wartortle'], 'bug': ['caterpie'], 'electric': ['raichu', 'pikachu', 'zapdos'], 'normal': ['jigglypuff', 'pidgey', 'rattata', 'fearow'], 'fairy': ['jigglypuff', 'clefairy'], 'grass': ['ivysaur', 'bulbasaur', 'venusaur'], 'poison': ['ivysaur', 'bulbasaur', 'venusaur'], 'fire': ['ninetales', 'charmeleon', 'charizard'], 'flying': ['pidgey', 'fearow', 'charizard', 'zapdos'], 'psychic': ['mewtwo', 'mew']}

# %%
# We only want the Driver Standings
#for x in range(5):
#    data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][x]['Driver']['familyName']
#    print(data)
for x in range(5):
    data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]["DriverStandings"][x]
    print(data)
my_racer_data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]["DriverStandings"]
# Out:
# {'position': '1', 'positionText': '1', 'points': '35', 'wins': '2', 'Driver': {'driverId': 'raikkonen', 'permanentNumber': '7', 'code': 'RAI', 'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen', 'givenName': 'Kimi', 'familyName': 'Räikkönen', 'dateOfBirth': '1979-10-17', 'nationality': 'Finnish'}, 'Constructors': [{'constructorId': 'ferrari', 'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari', 'name': 'Ferrari', 'nationality': 'Italian'}]}
# {'position': '2', 'positionText': '2', 'points': '28', 'wins': '2', 'Driver': {'driverId': 'massa', 'permanentNumber': '19', 'code': 'MAS', 'url': 'http://en.wikipedia.org/wiki/Felipe_Massa', 'givenName': 'Felipe', 'familyName': 'Massa', 'dateOfBirth': '1981-04-25', 'nationality': 'Brazilian'}, 'Constructors': [{'constructorId': 'ferrari', 'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari', 'name': 'Ferrari', 'nationality': 'Italian'}]}
# ...

# %%
def get_racer_info(data):
    new_data = []
    for racer in data:
        racer_dict = {}
        racer_name = f'{racer["Driver"]["givenName"]} {racer["Driver"]["familyName"]}'        
        racer_dict[racer_name] = {
            'frist_name' : racer["Driver"]["givenName"],
            'last_name': racer["Driver"]["familyName"],
            'position':racer['position'],
            'wins': racer["wins"],
            'DOB':racer["Driver"]["dateOfBirth"],
            'nationality': racer["Driver"]['nationality'],
            'constructors': racer['Constructors'][0]["name"] 
        }
        new_data.append(racer_dict)
    return new_data
get_racer_info(my_racer_data)
# Out:
# [{'Kimi Räikkönen': {'frist_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'constructors': 'Ferrari'}},
#  {'Felipe Massa': {'frist_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'constructors': 'Ferrari'}},
#  {'Lewis Hamilton': {'frist_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructors': 'McLaren'}},
#  {'Robert Kubica': {'frist_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'constructors': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'frist_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year, r):
    url = f'http://ergast.com/api/f1/{year}/{r}/driverStandings.json'
    if not response.json()['MRData']['StandingsTable']['StandingsLists']:
        return "We had an error loading data year or round not in data base"
    data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2019,4)
# Out:
# [{'Kimi Räikkönen': {'frist_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'constructors': 'Ferrari'}},
#  {'Felipe Massa': {'frist_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'constructors': 'Ferrari'}},
#  {'Lewis Hamilton': {'frist_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructors': 'McLaren'}},
#  {'Robert Kubica': {'frist_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'constructors': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'frist_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
#url = "https://pokeapi.co/api/v2/pokemon/charmander"
#pokemon = requests.get(url)
#Testing if we have a valid connection
#print(response)
#type(response.json())

#One Abibility Name
#chamrmander_ability = pokemon.json()["abilities"][0]["ability"]["name"]
#showing I have a valid connnection
#print(pokemon)

#Pokemon one: Name, One Ability's Name, Base_experience, and URL for front_shiny, base_state, hp base_stat, defense base_stat
#charmander_name = "Charmander"
#url = "https://pokeapi.co/api/v2/pokemon/charmander"
#chamrmander_ability = pokemon.json()["abilities"][0]["ability"]["name"]
#print(chamrmander_ability)
#charmander_base_experience = pokemon.json()["base_experience"]
#print(charmander_base_experience)
#charmander_shinty_front_Sprites = pokemon.json()['sprites']['front_shiny']
#print(charmander_shinty_front_Sprites)
#charmander_wieght = pokemon.json()["weight"]
#print(charmander_wieght)
#pokemon_ability_list = []
#for ele in pokemon.json()["stats"]:
#    pokemon_ability_list.append(f'{ele["stat"]["name"]} {ele["base_stat"]}')
#print(pokemon_ability_list)
#pokemon_type = ""
#for ele in pokemon.json()["types"]:
#    if pokemon.json()["types"] == 2:
#        pokemon_type += f'{ele["type"]["name"]}+{ele["type"]["name"]}'
#    else:
#        pokemon_type += f'{ele["type"]["name"]}'
#
#print(pokemon_type)
#
#print(pokemon.json()["stats"][1]["stat"]["url"])

def pokemon_dict(pokemon):
    #retrieves from the internet the information
    url = f"https://pokeapi.co/api/v2/pokemon/{pokemon}"
    pokemon_data = requests.get(url)
    #creates a list of stats
    pokemon_stat_list = []
    for ele in pokemon_data.json()["stats"]:
        pokemon_stat_list.append(f'{ele["stat"]["name"]} {ele["base_stat"]}')
    #retreives the types from the list of types   
    pokemon_type = ""
    for ele in pokemon_data.json()["types"]:
        pokemon_type += f'{ele["type"]["name"]} '
    
    #Makes the dictionary to be returned
    guide = {
        "name": f'{pokemon}',
        "Pokemon Ability": pokemon_data.json()["abilities"][0]["ability"]["name"],
        "Pokemon Base Exp": pokemon_data.json()["base_experience"],
        "Pokemon shiny front sprites":pokemon_data.json()['sprites']['front_shiny'],
        "Pokemon Wieght":pokemon_data.json()["weight"],
        "Pokemon Stat List":pokemon_stat_list,
        "Pokemon Types": pokemon_type.strip()
              
        
    }
    return guide

print(pokemon_dict("charizard"))
print(pokemon_dict("charmeleon"))
print(pokemon_dict("bulbasaur"))
print(pokemon_dict("ivysaur"))
print(pokemon_dict("venusaur"))
# Out:
# {'name': 'charizard', 'Pokemon Ability': 'blaze', 'Pokemon Base Exp': 267, 'Pokemon shiny front sprites': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/6.png', 'Pokemon Wieght': 905, 'Pokemon Stat List': ['hp 78', 'attack 84', 'defense 78', 'special-attack 109', 'special-defense 85', 'speed 100'], 'Pokemon Types': 'fire flying'}
# {'name': 'charmeleon', 'Pokemon Ability': 'blaze', 'Pokemon Base Exp': 142, 'Pokemon shiny front sprites': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/5.png', 'Pokemon Wieght': 190, 'Pokemon Stat List': ['hp 58', 'attack 64', 'defense 58', 'special-attack 80', 'special-defense 65', 'speed 80'], 'Pokemon Types': 'fire'}
# ...

# %%
#import the packages we need:
import requests, json

def pokemon_dict(pokemon):
    #retrieves from the internet the information
    url = f"https://pokeapi.co/api/v2/pokemon/{pokemon}"
    pokemon_data = requests.get(url)
    #creates a list of stats
    pokemon_stat_list = []
    for ele in pokemon_data.json()["stats"]:
        pokemon_stat_list.append(f'{ele["stat"]["name"]} {ele["base_stat"]}')
    #retreives the types from the list of types   
    pokemon_type = ""
    for ele in pokemon_data.json()["types"]:
        pokemon_type += f'{ele["type"]["name"]} '
    
    #Makes the dictionary to be returned
    guide = {
        "name": f'{pokemon}',
        "Pokemon Ability": pokemon_data.json()["abilities"][0]["ability"]["name"],
        "Pokemon Base Exp": pokemon_data.json()["base_experience"],
        "Pokemon shiny front sprites":pokemon_data.json()['sprites']['front_shiny'],
        "Pokemon Wieght":pokemon_data.json()["weight"],
        "Pokemon Stat List":pokemon_stat_list,
        "Pokemon Types": pokemon_type.strip()
              
        
    }
    return guide

list_pokemon = ["squirtle","blastoise","caterpie","raichu","jigglypuff",
                "ivysaur","ninetales","clefairy","pikachu","bulbasaur",
                "venusaur","pidgey","charmeleon","wartortle","rattata",
                "fearow", "charizard","mewtwo","mew","zapdos"]
all_pokemon = {}
for pokemon_name in list_pokemon:
    name = pokemon_dict(pokemon_name)["name"]
    info = {
        "Wieght":pokemon_dict(pokemon_name)["Pokemon Wieght"],
        "stat list":pokemon_dict(pokemon_name)["Pokemon Stat List"],
        "Abilities":pokemon_dict(pokemon_name)["Pokemon Ability"],
    }
    all_pokemon[name] = info
type_dict = {}
for pokemon_name in list_pokemon:
    type_pokemon = pokemon_dict(pokemon_name)["Pokemon Types"]
    if type_pokemon not in type_dict:
        type_dict[type_pokemon] = {}
    type_dict[type_pokemon][pokemon_name] = all_pokemon[pokemon_name]

print(type_dict)
print(type_dict["water"])
print(type_dict["fire"])
# Out:
# {'water': {'squirtle': {'Wieght': 90, 'stat list': ['hp 44', 'attack 48', 'defense 65', 'special-attack 50', 'special-defense 64', 'speed 43'], 'Abilities': 'torrent'}, 'blastoise': {'Wieght': 855, 'stat list': ['hp 79', 'attack 83', 'defense 100', 'special-attack 85', 'special-defense 105', 'speed 78'], 'Abilities': 'torrent'}, 'wartortle': {'Wieght': 225, 'stat list': ['hp 59', 'attack 63', 'defense 80', 'special-attack 65', 'special-defense 80', 'speed 58'], 'Abilities': 'torrent'}}, 'bug': {'caterpie': {'Wieght': 29, 'stat list': ['hp 45', 'attack 30', 'defense 35', 'special-attack 20', 'special-defense 20', 'speed 45'], 'Abilities': 'shield-dust'}}, 'electric': {'raichu': {'Wieght': 300, 'stat list': ['hp 60', 'attack 90', 'defense 55', 'special-attack 90', 'special-defense 80', 'speed 110'], 'Abilities': 'static'}, 'pikachu': {'Wieght': 60, 'stat list': ['hp 35', 'attack 55', 'defense 40', 'special-attack 50', 'special-defense 50', 'speed 90'], 'Abilities': 'static'}}, 'normal 
# ...
